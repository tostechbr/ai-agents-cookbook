# %%
# Install dependencies
# %pip install -qU langgraph langchain langchain_openai
# Out:
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Load environment variables from .env file (if it exists)
load_dotenv()

# If not found in .env, ask for it
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = input("Enter your OpenAI API Key: ")

# %% [markdown]
# ### Exercise 1: Define a Tool
#
# Create a simple python function `get_weather(city: str)` that returns a fake weather report.

# %%
# Your code here
def get_weather(city: str) -> str:
    """Returns the weather for a given city."""
    return f"The weather in {city} is Sunny and 25°C."

# %% [markdown]
# ### Exercise 2: Bind Tool to LLM
#
# Initialize a `ChatOpenAI` model and use `.bind_tools()` to attach the weather function.

# %%
# Your code here
llm = ChatOpenAI(model="gpt-4.1", temperature=0)
tools = [get_weather]
llm_with_tools = llm.bind_tools(tools)

# Test it
msg = llm_with_tools.invoke("What is the weather in Tokyo?")
print(msg.tool_calls)
# Out:
# [{'name': 'get_weather', 'args': {'city': 'Tokyo'}, 'id': 'call_Ore5p2EspTWoIOT0JDUYSjLn', 'type': 'tool_call'}]
